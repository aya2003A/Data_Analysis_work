# %% [markdown]
# # Assessing & Exploring
# Use [README file](http://www.fueleconomy.gov/feg/epadata/Readme.txt) or [This pdf](http://www.fueleconomy.gov/feg/EPAGreenGuide/GreenVehicleGuideDocumentation.pdf) to know more abou the datasets and columns\
# Explore `all_alpha_08.csv` and `all_alpha_18.csv` and the questions below.

# %%
# 1- number of samples in each dataset?
# 2- number of columns in each dataset? 
# 3- duplicate rows in each dataset? 
# 4- number of features with missing values in both datasets?
# 5- datatypes of columns in each dataset ?
# 6- How many columns are different from each other (that do not share the same datatype) [type the name of columns]?
#           
# 7- number of non-null unique values for features in each dataset for each column (do not type anything just the code)?
# 8- how is the column "cyl" different in both datasets? (checkbox)
#                  A- Datatype  B- Number of unique value C- No of samples
# 9- What are the types of fuel present in each dataset ?
# 10- What are the fuel types that exist in a dataset and not the other?

# %%
# import
import pandas as pd
import numpy as np
eight=pd.read_csv('all_alpha_08.csv')
eighteen=pd.read_csv('all_alpha_18.csv')

# %%
eight
# Out:
#             Model  Displ      Cyl    Trans Drive      Fuel Sales Area Stnd  \
# 0       ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# 1       ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         FA   B5
# 2       ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# 3       ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline         FA   B5
# 4        ACURA RL    3.5  (6 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# ...           ...    ...      ...      ...   ...       ...        ...  ...
# 2399  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   4WD  Gasoline         CA   U2
# 2400  VOLVO XC 90    4.4  (8 cyl)  Auto-S6   4WD  Gasoline         CA   U2
# 2401  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   2WD  Gasoline         FA   B5
# 2402  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   4WD  Gasoline         FA   B5
# 2403  VOLVO XC 90    4.4  (8 cyl)  Auto-S6   4WD  Gasoline         FA   B5
#
#       Underhood ID    Veh Class Air Pollution Score FE Calc Appr City MPG  \
# 0     8HNXT03.7PKR          SUV                   7          Drv       15
# 1     8HNXT03.7PKR          SUV                   6          Drv       15
# 2     8HNXT02.3DKR          SUV                   7          Drv       17
# 3     8HNXT02.3DKR          SUV                   6          Drv       17
# 4     8HNXV03.5HKR  midsize car                   7          Drv       16
# ...            ...          ...                 ...          ...      ...
# 2399  8VVXB03.2U2N          SUV                   7          Drv       14
# 2400  8VVXB04.4U2N          SUV                   7          Drv       13
# 2401  8VVXB03.2U2N          SUV                   6          Drv       14
# 2402  8VVXB03.2U2N          SUV                   6          Drv       14
# 2403  8VVXB04.4U2N          SUV                   6          Drv       13
#
#      Hwy MPG Cmb MPG  Unadj Cmb MPG Greenhouse Gas Score SmartWay
# 0         20      17        22.0527                    4       no
# 1         20      17        22.0527                    4       no
# 2         22      19        24.1745                    5       no
# 3         22      19        24.1745                    5       no
# 4         24      19        24.5629                    5       no
# ...      ...     ...            ...                  ...      ...
# 2399      20      16        20.7134                    4       no
# 2400      19      15        19.4789                    3       no
# 2401      20      16        20.9644                    4       no
# 2402      20      16        20.7134                    4       no
# 2403      19      15        19.4789                    3       no
#
# [2404 rows x 18 columns]

# %%
eighteen
# Out:
#             Model  Displ  Cyl       Trans Drive                  Fuel  \
# 0       ACURA RDX    3.5  6.0  SemiAuto-6   2WD              Gasoline
# 1       ACURA RDX    3.5  6.0  SemiAuto-6   2WD              Gasoline
# 2       ACURA RDX    3.5  6.0  SemiAuto-6   4WD              Gasoline
# 3       ACURA RDX    3.5  6.0  SemiAuto-6   4WD              Gasoline
# 4       ACURA TLX    2.4  4.0       AMS-8   2WD              Gasoline
# ...           ...    ...  ...         ...   ...                   ...
# 1606  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD              Gasoline
# 1607  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD              Gasoline
# 1608  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD              Gasoline
# 1609  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD  Gasoline/Electricity
# 1610  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD  Gasoline/Electricity
#
#      Cert Region       Stnd            Stnd Description  Underhood ID  \
# 0             FA     T3B125      Federal Tier 3 Bin 125  JHNXT03.5GV3
# 1             CA         U2      California LEV-II ULEV  JHNXT03.5GV3
# 2             FA     T3B125      Federal Tier 3 Bin 125  JHNXT03.5GV3
# 3             CA         U2      California LEV-II ULEV  JHNXT03.5GV3
# 4             CA  L3ULEV125  California LEV-III ULEV125  JHNXV02.4WH3
# ...          ...        ...                         ...           ...
# 1606          FA      T3B70       Federal Tier 3 Bin 70  JVVXJ02.0A70
# 1607          CA   L3ULEV70   California LEV-III ULEV70  JVVXJ02.0B70
# 1608          FA      T3B70       Federal Tier 3 Bin 70  JVVXJ02.0B70
# 1609          CA  L3SULEV30  California LEV-III SULEV30  JVVXJ02.0P30
# 1610          FA      T3B30       Federal Tier 3 Bin 30  JVVXJ02.0P30
#
#          Veh Class  Air Pollution Score City MPG Hwy MPG Cmb MPG  \
# 0        small SUV                    3       20      28      23
# 1        small SUV                    3       20      28      23
# 2        small SUV                    3       19      27      22
# 3        small SUV                    3       19      27      22
# 4        small car                    3       23      33      27
# ...            ...                  ...      ...     ...     ...
# 1606  standard SUV                    5       22      28      24
# 1607  standard SUV                    5       20      27      23
# 1608  standard SUV                    5       20      27      23
# 1609  standard SUV                    7    26/63   30/61   27/62
# 1610  standard SUV                    7    26/63   30/61   27/62
#
#       Greenhouse Gas Score SmartWay Comb CO2
# 0                        5       No      386
# 1                        5       No      386
# 2                        4       No      402
# 3                        4       No      402
# 4                        6       No      330
# ...                    ...      ...      ...
# 1606                     5       No      365
# 1607                     5       No      394
# 1608                     5       No      394
# 1609                    10    Elite      187
# 1610                    10    Elite      187
#
# [1611 rows x 18 columns]

# %%
# 1- number of samples and columns in each dataset? 
row1,col1=eight.shape
row2,col2=eighteen.shape
print("number of samples in all_alpha_08 ",row1,"number of col in all_alpha_08 ",col1)
print("number of samples in all_alpha_18 ",row2,"number of col in all_alpha_18 ",col2)
# Out:
# number of samples in all_alpha_08  2404 number of col in all_alpha_08  18
# number of samples in all_alpha_18  1611 number of col in all_alpha_18  18

# %%
# 3- duplicate rows in each dataset?
print("number of duplicate in all_alpha_08 ",sum(eight.duplicated()))
print("number of duplicate in all_alpha_18 ",sum(eighteen.duplicated()))
# Out:
# number of duplicate in all_alpha_08  25
# number of duplicate in all_alpha_18  0

# %%
# 4- number of features with missing values in 2008?
print("number of features with missing values in all_alpha_08 ",eight.isnull().sum())
# Out:
# number of features with missing values in all_alpha_08  Model                     0
# Displ                     0
# Cyl                     199
# Trans                   199
# Drive                    93
# Fuel                      0
# Sales Area                0
# Stnd                      0
# Underhood ID              0
# Veh Class                 0
# Air Pollution Score       0
# FE Calc Appr            199
# City MPG                199
# Hwy MPG                 199
# Cmb MPG                 199
# Unadj Cmb MPG           199
# Greenhouse Gas Score    199
# SmartWay                  0
# dtype: int64

# %%
# 4- number of features with missing values in 2018?
print("number of features with missing values in all_alpha_18 ",eighteen.isnull().sum())
# Out:
# number of features with missing values in all_alpha_18  Model                   0
# Displ                   2
# Cyl                     2
# Trans                   0
# Drive                   0
# Fuel                    0
# Cert Region             0
# Stnd                    0
# Stnd Description        0
# Underhood ID            0
# Veh Class               0
# Air Pollution Score     0
# City MPG                0
# Hwy MPG                 0
# Cmb MPG                 0
# Greenhouse Gas Score    0
# SmartWay                0
# Comb CO2                0
# dtype: int64

# %%
# 5- datatypes of columns in each dataset ?
eight.dtypes
# Out:
# Model                    object
# Displ                   float64
# Cyl                      object
# Trans                    object
# Drive                    object
# Fuel                     object
# Sales Area               object
# Stnd                     object
# Underhood ID             object
# Veh Class                object
# Air Pollution Score      object
# FE Calc Appr             object
# City MPG                 object
# Hwy MPG                  object
# Cmb MPG                  object
# Unadj Cmb MPG           float64
# Greenhouse Gas Score     object
# SmartWay                 object
# dtype: object

# %%
eighteen.dtypes
# Out:
# Model                    object
# Displ                   float64
# Cyl                     float64
# Trans                    object
# Drive                    object
# Fuel                     object
# Cert Region              object
# Stnd                     object
# Stnd Description         object
# Underhood ID             object
# Veh Class                object
# Air Pollution Score       int64
# City MPG                 object
# Hwy MPG                  object
# Cmb MPG                  object
# Greenhouse Gas Score      int64
# SmartWay                 object
# Comb CO2                 object
# dtype: object

# %%
#6- How many columns are different from each other (that do not share the same datatype) [type the name of columns]?
difference_col=eight.columns.difference(eighteen.columns)
difference_col
difference_col2=eighteen.columns.difference(eight.columns)
difference_col2
print(difference_col,difference_col2)
# Out:
# Index(['FE Calc Appr', 'Sales Area', 'Unadj Cmb MPG'], dtype='object') Index(['Cert Region', 'Comb CO2', 'Stnd Description'], dtype='object')

# %%
# 7- number of non-null unique values for features in each dataset for each column (do not type anything just the code)
eight.nunique().sum()
# Out:
# 1757

# %%
eighteen.nunique().sum()
# Out:
# 1217

# %%
# 8- how is the column "Cyl" different in both datasets? 
#data types are different & length
eight['Cyl'].info
# Out:
# <bound method Series.info of 0       (6 cyl)
# 1       (6 cyl)
# 2       (4 cyl)
# 3       (4 cyl)
# 4       (6 cyl)
#          ...
# 2399    (6 cyl)
# 2400    (8 cyl)
# 2401    (6 cyl)
# 2402    (6 cyl)
# 2403    (8 cyl)
# Name: Cyl, Length: 2404, dtype: object>

# %%
eighteen['Cyl'].info
# Out:
# <bound method Series.info of 0       6.0
# 1       6.0
# 2       6.0
# 3       6.0
# 4       4.0
#        ...
# 1606    4.0
# 1607    4.0
# 1608    4.0
# 1609    4.0
# 1610    4.0
# Name: Cyl, Length: 1611, dtype: float64>

# %%
# 9- What are the types of fuel present in each dataset ?
eight['Fuel'].unique()
# Out:
# array(['Gasoline', 'ethanol/gas', 'ethanol', 'diesel', 'CNG'],
#       dtype=object)

# %%
# 10- What are the types of fuel present in each dataset ?
eighteen['Fuel'].unique()
# Out:
# array(['Gasoline', 'Gasoline/Electricity', 'Diesel', 'Ethanol/Gas',
#        'Electricity'], dtype=object)

# %% [markdown]
# # Cleaning

# %% [markdown]
# ## Cleaning - Column Labels

# %% [markdown]
# Drop features that aren't consistent (not present in both datasets) or aren't relevant to our questions.
#
# Columns to Drop:\
# From 2008 dataset: 'Stnd', 'Underhood ID', 'FE Calc Appr', 'Unadj Cmb MPG'\
# From 2018 dataset: 'Stnd', 'Stnd Description', 'Underhood ID', 'Comb CO2'

# %%
# drop the columns from 2008
eight.drop(['Stnd', 'Underhood ID', 'FE Calc Appr', 'Unadj Cmb MPG'], axis=1, inplace=True)
eight
# Out:
#             Model  Displ      Cyl    Trans Drive      Fuel Sales Area  \
# 0       ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         CA
# 1       ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         FA
# 2       ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline         CA
# 3       ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline         FA
# 4        ACURA RL    3.5  (6 cyl)  Auto-S5   4WD  Gasoline         CA
# ...           ...    ...      ...      ...   ...       ...        ...
# 2399  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   4WD  Gasoline         CA
# 2400  VOLVO XC 90    4.4  (8 cyl)  Auto-S6   4WD  Gasoline         CA
# 2401  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   2WD  Gasoline         FA
# 2402  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   4WD  Gasoline         FA
# 2403  VOLVO XC 90    4.4  (8 cyl)  Auto-S6   4WD  Gasoline         FA
#
#         Veh Class Air Pollution Score City MPG Hwy MPG Cmb MPG  \
# 0             SUV                   7       15      20      17
# 1             SUV                   6       15      20      17
# 2             SUV                   7       17      22      19
# 3             SUV                   6       17      22      19
# 4     midsize car                   7       16      24      19
# ...           ...                 ...      ...     ...     ...
# 2399          SUV                   7       14      20      16
# 2400          SUV                   7       13      19      15
# 2401          SUV                   6       14      20      16
# 2402          SUV                   6       14      20      16
# 2403          SUV                   6       13      19      15
#
#      Greenhouse Gas Score SmartWay
# 0                       4       no
# 1                       4       no
# 2                       5       no
# 3                       5       no
# 4                       5       no
# ...                   ...      ...
# 2399                    4       no
# 2400                    3       no
# 2401                    4       no
# 2402                    4       no
# 2403                    3       no
#
# [2404 rows x 14 columns]

# %%
# drop the columns from 2018
eighteen.drop(['Stnd', 'Stnd Description', 'Underhood ID', 'Comb CO2'], axis=1, inplace=True)
eighteen
# Out:
#             Model  Displ  Cyl       Trans Drive                  Fuel  \
# 0       ACURA RDX    3.5  6.0  SemiAuto-6   2WD              Gasoline
# 1       ACURA RDX    3.5  6.0  SemiAuto-6   2WD              Gasoline
# 2       ACURA RDX    3.5  6.0  SemiAuto-6   4WD              Gasoline
# 3       ACURA RDX    3.5  6.0  SemiAuto-6   4WD              Gasoline
# 4       ACURA TLX    2.4  4.0       AMS-8   2WD              Gasoline
# ...           ...    ...  ...         ...   ...                   ...
# 1606  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD              Gasoline
# 1607  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD              Gasoline
# 1608  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD              Gasoline
# 1609  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD  Gasoline/Electricity
# 1610  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD  Gasoline/Electricity
#
#      Cert Region     Veh Class  Air Pollution Score City MPG Hwy MPG Cmb MPG  \
# 0             FA     small SUV                    3       20      28      23
# 1             CA     small SUV                    3       20      28      23
# 2             FA     small SUV                    3       19      27      22
# 3             CA     small SUV                    3       19      27      22
# 4             CA     small car                    3       23      33      27
# ...          ...           ...                  ...      ...     ...     ...
# 1606          FA  standard SUV                    5       22      28      24
# 1607          CA  standard SUV                    5       20      27      23
# 1608          FA  standard SUV                    5       20      27      23
# 1609          CA  standard SUV                    7    26/63   30/61   27/62
# 1610          FA  standard SUV                    7    26/63   30/61   27/62
#
#       Greenhouse Gas Score SmartWay
# 0                        5       No
# 1                        5       No
# 2                        4       No
# 3                        4       No
# 4                        6       No
# ...                    ...      ...
# 1606                     5       No
# 1607                     5       No
# 1608                     5       No
# 1609                    10    Elite
# 1610                    10    Elite
#
# [1611 rows x 14 columns]

# %% [markdown]
# ## Cleaning -  Rename Columns
# **Change the "Sales Area" column label in the 2008 dataset to "Cert Region" for consistency.**\
# **Rename all column labels to replace spaces with underscores and convert everything to lowercase.**\
# (Underscores can be much easier to work with in Python than spaces.\
# For example, having spaces wouldn't allow you to use df.column_name instead of df['column_name'] to select columns or use query().\
# Being consistent with lowercase and underscores also helps make column names easy to remember.)

# %%
# rename the column
eight.rename(columns = {'Sales Area':'Cert Region'}, inplace = True)

# %%
# fix columns in both datasets
eight.columns = eight.columns.str.replace(' ', '_')
eight.head()
# Out:
#        Model  Displ      Cyl    Trans Drive      Fuel Cert_Region  \
# 0  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline          CA
# 1  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline          FA
# 2  ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline          CA
# 3  ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline          FA
# 4   ACURA RL    3.5  (6 cyl)  Auto-S5   4WD  Gasoline          CA
#
#      Veh_Class Air_Pollution_Score City_MPG Hwy_MPG Cmb_MPG  \
# 0          SUV                   7       15      20      17
# 1          SUV                   6       15      20      17
# 2          SUV                   7       17      22      19
# 3          SUV                   6       17      22      19
# 4  midsize car                   7       16      24      19
#
#   Greenhouse_Gas_Score SmartWay
# 0                    4       no
# 1                    4       no
# 2                    5       no
# 3                    5       no
# 4                    5       no

# %%
eighteen.columns = eighteen.columns.str.replace(' ', '_')
eighteen.head()
# Out:
#        Model  Displ  Cyl       Trans Drive      Fuel Cert_Region  Veh_Class  \
# 0  ACURA RDX    3.5  6.0  SemiAuto-6   2WD  Gasoline          FA  small SUV
# 1  ACURA RDX    3.5  6.0  SemiAuto-6   2WD  Gasoline          CA  small SUV
# 2  ACURA RDX    3.5  6.0  SemiAuto-6   4WD  Gasoline          FA  small SUV
# 3  ACURA RDX    3.5  6.0  SemiAuto-6   4WD  Gasoline          CA  small SUV
# 4  ACURA TLX    2.4  4.0       AMS-8   2WD  Gasoline          CA  small car
#
#    Air_Pollution_Score City_MPG Hwy_MPG Cmb_MPG  Greenhouse_Gas_Score SmartWay
# 0                    3       20      28      23                     5       No
# 1                    3       20      28      23                     5       No
# 2                    3       19      27      22                     4       No
# 3                    3       19      27      22                     4       No
# 4                    3       23      33      27                     6       No

# %%
# confirm that both datasets share the exact column names:
eight.columns = eight.columns.str.lower()
eight.head()
# Out:
#        model  displ      cyl    trans drive      fuel cert_region  \
# 0  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline          CA
# 1  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline          FA
# 2  ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline          CA
# 3  ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline          FA
# 4   ACURA RL    3.5  (6 cyl)  Auto-S5   4WD  Gasoline          CA
#
#      veh_class air_pollution_score city_mpg hwy_mpg cmb_mpg  \
# 0          SUV                   7       15      20      17
# 1          SUV                   6       15      20      17
# 2          SUV                   7       17      22      19
# 3          SUV                   6       17      22      19
# 4  midsize car                   7       16      24      19
#
#   greenhouse_gas_score smartway
# 0                    4       no
# 1                    4       no
# 2                    5       no
# 3                    5       no
# 4                    5       no

# %%
eighteen.columns = eighteen.columns.str.lower()
eighteen.head()
# Out:
#        model  displ  cyl       trans drive      fuel cert_region  veh_class  \
# 0  ACURA RDX    3.5  6.0  SemiAuto-6   2WD  Gasoline          FA  small SUV
# 1  ACURA RDX    3.5  6.0  SemiAuto-6   2WD  Gasoline          CA  small SUV
# 2  ACURA RDX    3.5  6.0  SemiAuto-6   4WD  Gasoline          FA  small SUV
# 3  ACURA RDX    3.5  6.0  SemiAuto-6   4WD  Gasoline          CA  small SUV
# 4  ACURA TLX    2.4  4.0       AMS-8   2WD  Gasoline          CA  small car
#
#    air_pollution_score city_mpg hwy_mpg cmb_mpg  greenhouse_gas_score smartway
# 0                    3       20      28      23                     5       No
# 1                    3       20      28      23                     5       No
# 2                    3       19      27      22                     4       No
# 3                    3       19      27      22                     4       No
# 4                    3       23      33      27                     6       No

# %%
# save the new datasets as "data_08_v1.csv" and 'data_18_v1.csv'.
eight.to_csv('data_08_v1.csv', index=False)
eighteen.to_csv('data_18_v1.csv', index=False)

# %% [markdown]
# ## Cleaning - Filter, Drop Nulls, Dedupe
# For consistency, only compare cars certified by California standards.\
# Filter both datasets using query to select only rows where "cert_region" is CA. Then, drop the cert_region columns, since it will no longer provide any useful information (we'll know every value is 'CA').
#
# Use `data_08_v1.csv` and `data_18_v1.csv` that you just saved

# %% [markdown]
# ### Filter by Certification Region

# %%
# filter datasets for rows following California standards using query
import pandas as pd
import numpy as np
eight = pd.read_csv('data_08_v1.csv')
eighteen = pd.read_csv('data_18_v1.csv')
#eight['cert_region'].info  eighteen['cert_region'].info  #CA
eight = eight.query('cert_region == "CA"')
eighteen = eighteen.query('cert_region == "CA"')

# %%
# confirm only certification region is California
eight['cert_region']
eight['cert_region'].unique()
# Out:
# array(['CA'], dtype=object)

# %%
eighteen['cert_region'].unique()
# Out:
# array(['CA'], dtype=object)

# %%
# drop certification region columns form both datasets
eighteen.drop('cert_region', axis=1, inplace=True)
eight.drop('cert_region', axis=1, inplace=True)

# %% [markdown]
# ### Drop Rows with Missing Values

# %%
# drop rows with any null values in both datasets
eight.dropna(axis=0,inplace=True)
eighteen.dropna(axis=0,inplace=True)

# %%
# checks if any of the columns have null values
print(eight.isnull().sum(),eighteen.isnull().sum())
# Out:
# model                   0
# displ                   0
# cyl                     0
# trans                   0
# drive                   0
# fuel                    0
# veh_class               0
# air_pollution_score     0
# city_mpg                0
# hwy_mpg                 0
# cmb_mpg                 0
# greenhouse_gas_score    0
# smartway                0
# dtype: int64 model                   0
# displ                   0
# cyl                     0
# trans                   0
# drive                   0
# fuel                    0
# veh_class               0
# air_pollution_score     0
# city_mpg                0
# hwy_mpg                 0
# cmb_mpg                 0
# greenhouse_gas_score    0
# smartway                0
# dtype: int64

# %% [markdown]
# ### Dedupe Data

# %%
# print number of duplicates in 2008 and 2018 datasets
print("in 2008",sum(eight.duplicated()),"in 2018",sum(eighteen.duplicated()),)
# Out:
# in 2008 23 in 2018 3

# %%
# drop duplicates in both datasets
eight.drop_duplicates(inplace=True)
eighteen.drop_duplicates(inplace=True)

# %%
# confirm your changes
print("duplicates in 2008",sum(eight.duplicated()),"duplicates in 2018",sum(eighteen.duplicated()),)
# Out:
# duplicates in 2008 0 duplicates in 2018 0

# %%
# check the shape of each dataset -- if the 2008 size isn't (986,13) and 2018 (794,13), you should probably cry.
print(eight.shape,eighteen.shape)
# Out:
# (986, 13) (794, 13)

# %%
# make a checkpoint in case you mess up anything later

# %% [markdown]
# ## Cleaning - Fixing Data Types

# %% [markdown]
# ### Fixing `cyl` Data Type
# - 2008: extract int from string
# - 2018: convert float to int

# %%
# extract int from string in cyl in the 2008 dataset
eight['cyl'] = eight['cyl'].astype('str').str.extractall('(\d+)').unstack().fillna('').sum(axis=1).astype(int)
eight['cyl']
# Out:
# 0       6
# 2       4
# 4       6
# 6       6
# 7       6
#        ..
# 2394    6
# 2396    6
# 2398    6
# 2399    6
# 2400    8
# Name: cyl, Length: 986, dtype: int32

# %%
# convert the data type of the "cyl" column in the 2018 dataset from float to int 
eighteen['cyl']=eighteen['cyl'].astype(int)

# %%
# verify that the data type of the column in both datasets is "int"
print(eight['cyl'].dtype)
print(eighteen['cyl'].dtype)
# Out:
# int32
# int32

# %% [markdown]
# ### Fixing `air_pollution_score` Data Type
# - 2008: convert string to float
# - 2018: convert int to float

# %%
# try to change the data type to float
eighteen['air_pollution_score'] = eighteen['air_pollution_score'].astype(float)
eight['air_pollution_score'] = eight['air_pollution_score'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20148\1363748742.py in <module>
#       1 # try to change the data type to float
#       2 eighteen['air_pollution_score'] = eighteen['air_pollution_score'].astype(float)
# ----> 3 eight['air_pollution_score'] = eight['air_pollution_score'].astype(float)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5910         else:
#    5911             # else, only a single dtype is given
# -> 5912             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913             return self._constructor(new_data).__finalize__(self, method="astype")
#    5914
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     417
#     418     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 419         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     420
#     421     def convert(
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     302                     applied = b.apply(f, **kwargs)
#     303                 else:
# --> 304                     applied = getattr(b, f)(**kwargs)
#     305             except (TypeError, NotImplementedError):
#     306                 if not ignore_failures:
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors)
#     578         values = self.values
#     579
# --> 580         new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     581
#     582         new_values = maybe_coerce_values(new_values)
#
# ~\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_array_safe(values, dtype, copy, errors)
#    1290
#    1291     try:
# -> 1292         new_values = astype_array(values, dtype, copy=copy)
#    1293     except (ValueError, TypeError):
#    1294         # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_array(values, dtype, copy)
#    1235
#    1236     else:
# -> 1237         values = astype_nansafe(values, dtype, copy=copy)
#    1238
#    1239     # in pandas we don't store numpy str dtypes, so convert to object
#
# ~\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy, skipna)
#    1179     if copy or is_object_dtype(arr.dtype) or is_object_dtype(dtype):
#    1180         # Explicit copy, or required since NumPy can't view from / to object.
# -> 1181         return arr.astype(dtype, copy=True)
#    1182
#    1183     return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: '6/4'

# %%
# you should have faced an error, get the row that caused that error
eight[eight.air_pollution_score == '6/4']
# Out:
#                    model  displ  cyl    trans drive         fuel  veh_class  \
# 1550  MERCEDES-BENZ C300    3.0    6  Auto-L7   2WD  ethanol/gas  small car
#
#      air_pollution_score city_mpg hwy_mpg cmb_mpg greenhouse_gas_score  \
# 1550                 6/4    13/18   19/25   15/21                  7/6
#
#      smartway
# 1550       no

# %% [markdown]
# # It's not just the air pollution score!
# The cars that have more than one type of fuel in a single row are hybrid (run on more than one type of fuel)! Multiple columns will be affected too!\
#     "If a vehicle can operate on more than one type of fuel, an estimate is provided for each fuel type."\
# This is why you can see that multiple columns contain more than one value

# %%
# You have two options here: (1) Split the row by "/" into two rows, (2) just drop the rows that contain the ("/") in any of the columns
# You will lose a point for each dataset if you go with the second option

# %%
# to split the rows---->
# 1- get the rows that contain / in the fuel column
# 2- make two copies of these rows
# 3- get a list of all columns that are affected (you can get them by looking at any row of the hybrid cars)
# 4- split the the row by / to two rows (one for each copy) for EACH COLUMN --> first copy should store the value before the / and the second one should store the one after the /  
# 5- drop the original row from the dataset
# 6- append the newely created rows to the original dataframe
# 7- repeat the process for each dataset (the list of columns will change in the 2018 set)

# %% [markdown]
# This is the row before splitting\
# ![Capture.PNG](attachment:Capture.PNG)

# %% [markdown]
# This what it should look like after splitting\
# ![Capture1.PNG](attachment:Capture1.PNG)

# %%
# check that there are no hybrid cars in the 2008 dataset anymore:
copy1=eight[eight['fuel'].str.contains('/')].copy() 
copy2=eight[eight['fuel'].str.contains('/')].copy() 
columns = ['fuel', 'air_pollution_score', 'city_mpg', 'hwy_mpg', 'cmb_mpg', 'greenhouse_gas_score']
for i in columns:
    copy1[i] ,copy2[i]= copy1[i].apply(lambda x: x.split("/")[0]),copy2[i].apply(lambda x: x.split("/")[1])
new_eight = copy1.append(copy2)
eight.drop(eight.index, inplace=True)
eight= eight.append(new_eight,ignore_index=True)
eight[eight['fuel'].str.contains('/')]
# Out:
# C:\Users\alaa\AppData\Local\Temp\ipykernel_20148\887426628.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_eight = copy1.append(copy2)
# C:\Users\alaa\AppData\Local\Temp\ipykernel_20148\887426628.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   eight= eight.append(new_eight,ignore_index=True)
# Empty DataFrame
# Columns: [model, displ, cyl, trans, drive, fuel, veh_class, air_pollution_score, city_mpg, hwy_mpg, cmb_mpg, greenhouse_gas_score, smartway]
# Index: []

# %% [markdown]
# ### Repeat this process for the 2018 dataset

# %%
# do whatever you did in the previous cells
copy1=eighteen[eighteen['fuel'].str.contains('/')].copy() 
copy2=eighteen[eighteen['fuel'].str.contains('/')].copy() 
columns =['fuel','city_mpg','hwy_mpg','cmb_mpg']

for i in columns:
    copy1[i] ,copy2[i]= copy1[i].apply(lambda x: x.split("/")[0]),copy2[i].apply(lambda x: x.split("/")[1])
new_eighteen = copy1.append(copy2)
eighteen.drop(eighteen.index, inplace=True)
eighteen= eighteen.append(new_eighteen,ignore_index=True)
eighteen[eighteen['fuel'].str.contains('/')]
# Out:
# C:\Users\alaa\AppData\Local\Temp\ipykernel_20148\2657526055.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_eighteen = copy1.append(copy2)
# C:\Users\alaa\AppData\Local\Temp\ipykernel_20148\2657526055.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   eighteen= eighteen.append(new_eighteen,ignore_index=True)
# Empty DataFrame
# Columns: [model, displ, cyl, trans, drive, fuel, veh_class, air_pollution_score, city_mpg, hwy_mpg, cmb_mpg, greenhouse_gas_score, smartway]
# Index: []

# %%
# now, try to change the data type again
eighteen['air_pollution_score'] = eighteen['air_pollution_score'].astype(float)
eight['air_pollution_score'] = eight['air_pollution_score'].astype(float)
# for 2008, convert string to float

# for 2018, convert int to float
print(eighteen['air_pollution_score'].dtype,eight['air_pollution_score'].dtype)
# Out:
# float64 float64

# %% [markdown]
# ## Fix `city_mpg`, `hwy_mpg`, `cmb_mpg` datatypes
#     2008 and 2018: convert string to float

# %%
# check the data type of the columns
print(eight['city_mpg'].dtype,eight['hwy_mpg'].dtype,eight['cmb_mpg'].dtype)
print(eighteen['city_mpg'].dtype,eighteen['hwy_mpg'].dtype,eighteen['cmb_mpg'].dtype)
# Out:
# object object object
# object object object

# %%
# convert to float
eighteen['city_mpg'] = eighteen['city_mpg'].astype(float)
eighteen['hwy_mpg'] = eighteen['hwy_mpg'].astype(float)
eighteen['cmb_mpg'] = eighteen['cmb_mpg'].astype(float)
eight['city_mpg'] = eight['city_mpg'].astype(float)
eight['hwy_mpg'] = eight['hwy_mpg'].astype(float)
eight['cmb_mpg'] = eight['cmb_mpg'].astype(float)

# %% [markdown]
# ## Fix `greenhouse_gas_score` datatype
#     2008: convert from float to int

# %%
# convert the data type from float to int in the 2008 dataset
eight['greenhouse_gas_score'] = eight['greenhouse_gas_score'].astype(np.int64)

# %%
#### check that all columns and their data type in the 2008 dataset matches excatly the ones in the 2018 dataset
#### all columns MUST be the same data type
print(eight.dtypes)
print(eighteen.dtypes)
# Out:
# model                    object
# displ                   float64
# cyl                       int32
# trans                    object
# drive                    object
# fuel                     object
# veh_class                object
# air_pollution_score     float64
# city_mpg                float64
# hwy_mpg                 float64
# cmb_mpg                 float64
# greenhouse_gas_score      int64
# smartway                 object
# dtype: object
# model                    object
# displ                   float64
# cyl                       int32
# trans                    object
# drive                    object
# fuel                     object
# veh_class                object
# air_pollution_score     float64
# city_mpg                float64
# hwy_mpg                 float64
# cmb_mpg                 float64
# greenhouse_gas_score      int64
# smartway                 object
# dtype: object

# %%
eight.dtypes == eighteen.dtypes
# Out:
# model                   True
# displ                   True
# cyl                     True
# trans                   True
# drive                   True
# fuel                    True
# veh_class               True
# air_pollution_score     True
# city_mpg                True
# hwy_mpg                 True
# cmb_mpg                 True
# greenhouse_gas_score    True
# smartway                True
# dtype: bool

# %%
# check the shape of both datasets
print(eight.shape,eighteen.shape)
# Out:
# (2, 13) (76, 13)

# %%
# Save your final CLEAN datasets as "clean_08.csv" and "clean_18.csv"
eight.to_csv('clean_08.csv', index=False)
eighteen.to_csv('clean_18.csv', index=False)
