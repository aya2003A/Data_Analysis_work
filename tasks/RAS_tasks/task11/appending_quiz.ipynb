# %% [markdown]
# # Appending Data
# First, import the necessary packages and load `winequality-red.csv` and `winequality-white.csv`.

# %%
# import numpy and pandas
import pandas as pd
import numpy as np
# load red and white wine datasets
red=pd.read_csv('winequality-red.csv',sep=';')
white=pd.read_csv('winequality-white.csv',sep=';')

# %% [markdown]
# ## Create Color Columns
# Create two arrays as long as the number of rows in the red and white dataframes that repeat the value “red” or “white.” NumPy offers really easy way to do this. Here’s the documentation for [NumPy’s repeat](https://docs.scipy.org/doc/numpy/reference/generated/numpy.repeat.html) function. Take a look and try it yourself.

# %%
# create color array for red dataframe
color_array_red=np.repeat('red', len(red))
# create color array for white dataframe
color_array_white=np.repeat('white', len(white))

# %% [markdown]
# Add arrays to the red and white dataframes. Do this by setting a new column called 'color' to the appropriate array.

# %%
red['color']=color_array_red
white['color']=color_array_white

# %% [markdown]
# Do the same for the white dataframe and use `head()` to confirm the change.

# %%
white.head()
red.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur-dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color
# 0      9.4        5   red
# 1      9.8        5   red
# 2      9.8        5   red
# 3      9.8        6   red
# 4      9.4        5   red

# %% [markdown]
# ## Combine DataFrames with Append
# Check the documentation for [Pandas' append](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.append.html) function and see if you can use this to figure out how to combine the dataframes.

# %%
# append the dataframes  (There are 3 ways to do this, can you use them all ? only 2 :)
wine= red.append(white,sort=False,ignore_index=True)
#df_wine = pd.merge(white, red, how='outer', on = 'color')

wine
#df_wine
# Out:
# C:\Users\alaa\AppData\Local\Temp\ipykernel_6492\924037099.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   wine= red.append(white,sort=False,ignore_index=True)
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
#       free_sulfur_dioxide  total_sulfur-dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 6492                 24.0                   NaN  0.99114  3.27       0.50
# 6493                 57.0                   NaN  0.99490  3.15       0.46
# 6494                 30.0                   NaN  0.99254  2.99       0.46
# 6495                 20.0                   NaN  0.98869  3.34       0.38
# 6496                 22.0                   NaN  0.98941  3.26       0.32
#
#       alcohol  quality  color  total_sulfur_dioxide
# 0         9.4        5    red                   NaN
# 1         9.8        5    red                   NaN
# 2         9.8        5    red                   NaN
# 3         9.8        6    red                   NaN
# 4         9.4        5    red                   NaN
# ...       ...      ...    ...                   ...
# 6492     11.2        6  white                  92.0
# 6493      9.6        5  white                 168.0
# 6494      9.4        6  white                 111.0
# 6495     12.8        7  white                 110.0
# 6496     11.8        6  white                  98.0
#
# [6497 rows x 14 columns]

# %% [markdown]
# ## Scroll to right, you will find a column filled with NaN values. Go watch the next video and get back here to solve the problem (This is necessary for the next tasks !!)

# %%
# fix column names (do not use the usual solution we used earlier in the previous tasks)
white.rename(columns = {'total_sulfur_dioxide':'Total_sulfur_dioxide'}, inplace = True)
red.rename(columns = {'total_sulfur-dioxide':'Total_sulfur_dioxide'}, inplace = True)

white['Total_sulfur_dioxide'] =  white['Total_sulfur_dioxide'].fillna(0)
red['Total_sulfur_dioxide'] =  red['Total_sulfur_dioxide'].fillna(0)
# merge the two datasets again after fixing the issue (keep the color column)
wine= red.append(white,sort=False,ignore_index=True)
#df_wine = pd.merge(white, red, how='outer', on = 'color')

wine
#df_wine
# Out:
# C:\Users\alaa\AppData\Local\Temp\ipykernel_6492\3987422273.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   wine= red.append(white,sort=False,ignore_index=True)
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
#       free_sulfur_dioxide  Total_sulfur_dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 6492                 24.0                  92.0  0.99114  3.27       0.50
# 6493                 57.0                 168.0  0.99490  3.15       0.46
# 6494                 30.0                 111.0  0.99254  2.99       0.46
# 6495                 20.0                 110.0  0.98869  3.34       0.38
# 6496                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality  color
# 0         9.4        5    red
# 1         9.8        5    red
# 2         9.8        5    red
# 3         9.8        6    red
# 4         9.4        5    red
# ...       ...      ...    ...
# 6492     11.2        6  white
# 6493      9.6        5  white
# 6494      9.4        6  white
# 6495     12.8        7  white
# 6496     11.8        6  white
#
# [6497 rows x 13 columns]

# %%
# Confirm your changes
wine
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
#       free_sulfur_dioxide  Total_sulfur_dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 6492                 24.0                  92.0  0.99114  3.27       0.50
# 6493                 57.0                 168.0  0.99490  3.15       0.46
# 6494                 30.0                 111.0  0.99254  2.99       0.46
# 6495                 20.0                 110.0  0.98869  3.34       0.38
# 6496                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality  color
# 0         9.4        5    red
# 1         9.8        5    red
# 2         9.8        5    red
# 3         9.8        6    red
# 4         9.4        5    red
# ...       ...      ...    ...
# 6492     11.2        6  white
# 6493      9.6        5  white
# 6494      9.4        6  white
# 6495     12.8        7  white
# 6496     11.8        6  white
#
# [6497 rows x 13 columns]

# %% [markdown]
# ## Save Combined Dataset
# Save your newly combined dataframe as `winequality_edited.csv`. Remember, set `index=False` to avoid saving with an unnamed column!

# %%
# save the dataframe
wine.to_csv('winequality_edited.csv',index=False)

# %%
# How many samples are there in the newely saved dataframe?______6497_____
# How many columns are there?_______14____
